# %%
import numpy as np
import pandas as pd
yt= pd.read_csv("Data/Top YouTube Channels Data .csv")
yt
# Out:
#     rank                                            youtuber  subscribers   \
# 0       1                                          T-Series      213000000
# 1       2                                    YouTube Movies      150000000
# 2       3                        Cocomelon - Nursery Rhymes      133000000
# 3       4                                         SET India      131000000
# 4       5                                             Music      116000000
# 5       6                                         PewDiePie      111000000
# 6       7                                           MrBeast       93900000
# 7       8                                   Kids Diana Show       93800000
# 8       9                                            Gaming       92100000
# 9      10                                        Like Nastya      91000000
# 10     11                                               WWE       87600000
# ...

# %%
yt.head()
# Out:
#    rank                      youtuber  subscribers      video views   \
# 0      1                    T-Series      213000000  188,073,919,029
# 1      2              YouTube Movies      150000000  167,122,746,349
# 2      3  Cocomelon - Nursery Rhymes      133000000  126,822,520,940
# 3      4                   SET India      131000000  101,541,977,714
# 4      5                       Music      116000000   78,437,871,689
#
#    video count           category   started
# 0       16708.0             Music       2006
# 1           NaN  Film & Animation       2015
# 2         751.0         Education       2006
# 3       78334.0             Shows       2006
# 4           NaN             Music       2013

# %%
yt.tail()
# Out:
#     rank              youtuber  subscribers     video views   video count   \
# 95     96          Markiplier       32600000  18,011,837,263        5129.0
# 96     97     Like Nastya ESP       32600000  15,144,858,210         584.0
# 97     98        Ryan's World       32400000  51,312,603,726        2155.0
# 98     99            ABP News       32300000   9,850,740,503      209351.0
# 99    100  Desi Music Factory       32200000   9,115,577,588         122.0
#
#           category   started
# 95          Gaming       2012
# 96   Entertainment       2017
# 97   Entertainment       2015
# 98  People & Blogs       2012
# 99           Music       2014

# %%
yt.columns
# Out:
# Index(['rank ', 'youtuber', 'subscribers ', 'video views ', 'video count ',
#        'category ', 'started '],
#       dtype='object')

# %%
yt['started ']
# Out:
# 0     2006
# 1     2015
# 2     2006
# 3     2006
# 4     2013
# 5     2010
# 6     2012
# 7     2015
# 8     2013
# 9     2016
# 10    2007
# 11    2014
# 12    2018
# 13    2016
# 14    2013
# 15    2016
# 16    2012
# 17    2007
# 18    2007
# 19    2012
# 20    2012
# 21    2008
# 22    2005
# 23    2010
# 24    2009
# 25    2011
# 26    2006
# 27    2013
# 28    2015
# 29    2008
# 30    2014
# 31    2007
# 32    2006
# 33    2009
# 34    2007
# 35    2009
# 36    2007
# 37    2011
# 38    2011
# 39    2014
# 40    2006
# 41    2006
# 42    2013
# 43    2014
# 44    2013
# 45    2011
# 46    2006
# 47    2013
# 48    2011
# 49    2017
# 50    2014
# 51    2008
# 52    2013
# 53    2012
# 54    2009
# 55    2017
# 56    2011
# 57    2012
# 58    2014
# 59    2006
# 60    2008
# 61    2005
# 62    2011
# 63    2014
# 64    2012
# 65    2006
# 66    2011
# 67    2014
# 68    2014
# 69    2010
# 70    2015
# 71    2005
# 72    2016
# 73    2011
# 74    2016
# 75    2012
# ...

# %%
#shows rows, columns
yt.shape
# Out:
# (100, 7)

# %%
# number of rows, columns, and data types
yt.info
# Out:
# <bound method DataFrame.info of     rank                                            youtuber  subscribers   \
# 0       1                                          T-Series      213000000
# 1       2                                    YouTube Movies      150000000
# 2       3                        Cocomelon - Nursery Rhymes      133000000
# 3       4                                         SET India      131000000
# 4       5                                             Music      116000000
# 5       6                                         PewDiePie      111000000
# 6       7                                           MrBeast       93900000
# 7       8                                   Kids Diana Show       93800000
# 8       9                                            Gaming       92100000
# 9      10                                        Like Nastya      91000000
# 10     11                                               WWE       87600000
# ...

# %%
# changes how many columns you see at once
pd.set_option('display.max_columns', 7)

# %%
# changes how many rows you see at once
pd.set_option('display.max_rows', 100)
